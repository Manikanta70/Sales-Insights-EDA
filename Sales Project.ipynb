# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Sales Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# ...

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hour              185950 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 14.2+ MB

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                0
# dtype: int64

# %%
df.describe()
# Out:
#             Order ID  Quantity Ordered     Price Each          Month  \
# count  185950.000000     185950.000000  185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735       7.059140
# std     51512.737110          0.442793     332.731330       3.502996
# min    141234.000000          1.000000       2.990000       1.000000
# 25%    185831.250000          1.000000      11.950000       4.000000
# 50%    230367.500000          1.000000      14.950000       7.000000
# 75%    275035.750000          1.000000     150.000000      10.000000
# max    319670.000000          9.000000    1700.000000      12.000000
#
#                Sales           Hour
# count  185950.000000  185950.000000
# mean      185.490917      14.413305
# std       332.919771       5.423416
# min         2.990000       0.000000
# 25%        11.950000      11.000000
# 50%        14.950000      15.000000
# 75%       150.000000      19.000000
# max      3400.000000      23.000000

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df.head(50)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0     295665          Macbook Pro Laptop                 1     1700.00
# 1     295666          LG Washing Machine                 1      600.00
# 2     295667        USB-C Charging Cable                 1       11.95
# 3     295668            27in FHD Monitor                 1      149.99
# 4     295669        USB-C Charging Cable                 1       11.95
# 5     295670       AA Batteries (4-pack)                 1        3.84
# 6     295671        USB-C Charging Cable                 1       11.95
# 7     295672        USB-C Charging Cable                 2       11.95
# 8     295673  Bose SoundSport Headphones                 1       99.99
# 9     295674      AAA Batteries (4-pack)                 4        2.99
# 10    295675        USB-C Charging Cable                 2       11.95
# 11    295676             ThinkPad Laptop                 1      999.99
# ...

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#    Order ID               Product  Quantity Ordered  Price Each  \
# 0    295665    Macbook Pro Laptop                 1     1700.00
# 1    295666    LG Washing Machine                 1      600.00
# 2    295667  USB-C Charging Cable                 1       11.95
# 3    295668      27in FHD Monitor                 1      149.99
# 4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# 1   600.00   New York City     7
# 2    11.95   New York City    18
# ...

# %%
new_cols=df['Purchase Address'].str.split(pat=',',n=2,expand=True)

# %%
new_cols
# Out:
#                     0               1          2
# 0       136 Church St   New York City   NY 10001
# 1          562 2nd St   New York City   NY 10001
# 2         277 Main St   New York City   NY 10001
# 3          410 6th St   San Francisco   CA 94016
# 4          43 Hill St         Atlanta   GA 30301
# ...               ...             ...        ...
# 185945    795 Pine St          Boston   MA 02215
# 185946   495 North St   New York City   NY 10001
# 185947   319 Ridge St   San Francisco   CA 94016
# 185948    916 Main St   San Francisco   CA 94016
# 185949    209 11th St         Atlanta   GA 30301
#
# [185686 rows x 3 columns]

# %%
new_cols.columns=['Street','State','ZIP_Code']

# %%
new_cols
# Out:
#                Street           State   ZIP_Code
# 0       136 Church St   New York City   NY 10001
# 1          562 2nd St   New York City   NY 10001
# 2         277 Main St   New York City   NY 10001
# 3          410 6th St   San Francisco   CA 94016
# 4          43 Hill St         Atlanta   GA 30301
# ...               ...             ...        ...
# 185945    795 Pine St          Boston   MA 02215
# 185946   495 North St   New York City   NY 10001
# 185947   319 Ridge St   San Francisco   CA 94016
# 185948    916 Main St   San Francisco   CA 94016
# 185949    209 11th St         Atlanta   GA 30301
#
# [185686 rows x 3 columns]

# %%
df=pd.concat([df,new_cols],axis=1)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df=df.rename(columns={"State":"City"})
df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0     295665          Macbook Pro Laptop                 1     1700.00
# 1     295666          LG Washing Machine                 1      600.00
# 2     295667        USB-C Charging Cable                 1       11.95
# 3     295668            27in FHD Monitor                 1      149.99
# 4     295669        USB-C Charging Cable                 1       11.95
# 5     295670       AA Batteries (4-pack)                 1        3.84
# 6     295671        USB-C Charging Cable                 1       11.95
# 7     295672        USB-C Charging Cable                 2       11.95
# 8     295673  Bose SoundSport Headphones                 1       99.99
# 9     295674      AAA Batteries (4-pack)                 4        2.99
# 10    295675        USB-C Charging Cable                 2       11.95
# 11    295676             ThinkPad Laptop                 1      999.99
# ...

# %%
state=df['ZIP_Code'].str.split(pat=" ",n=2,expand=True)
state
# Out:
#        0    1      2
# 0          NY  10001
# 1          NY  10001
# 2          NY  10001
# 3          CA  94016
# 4          GA  30301
# ...    ..  ..    ...
# 185945     MA  02215
# 185946     NY  10001
# 185947     CA  94016
# 185948     CA  94016
# 185949     GA  30301
#
# [185686 rows x 3 columns]

# %%
df=pd.concat([df,state],axis=1)
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df.drop(columns=0,inplace=True)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df=df.rename(columns={1:"State Code",2:"ZIP"})
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df=df.drop(columns='ZIP_Code',axis=1)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
df=df.drop(columns='Purchase Address',axis=1)
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date  Month    Sales            City  Hour  \
# ...

# %%
df.iloc[325]
# Out:
# Order ID                           295970
# Product             AA Batteries (4-pack)
# Quantity Ordered                        1
# Price Each                           3.84
# Order Date            2019-12-03 23:08:00
# Month                                  12
# Sales                                3.84
# City                               Boston
# Hour                                   23
# Street                       414 Adams St
# City                               Boston
# State Code                             MA
# ZIP                                 02215
# Name: 325, dtype: object

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date  Month    Sales            City  Hour  \
# ...

# %%
df[50:150]
# Out:
#      Order ID                     Product  Quantity Ordered  Price Each  \
# 50     295710      AAA Batteries (4-pack)                 1        2.99
# 51     295711      AAA Batteries (4-pack)                 2        2.99
# 52     295712          Macbook Pro Laptop                 1     1700.00
# 53     295713  Bose SoundSport Headphones                 1       99.99
# 54     295714                      iPhone                 1      700.00
# ..        ...                         ...               ...         ...
# 145    295796    Lightning Charging Cable                 1       14.95
# 146    295797            Wired Headphones                 1       11.99
# 147    295798            Wired Headphones                 1       11.99
# 148    295799      AAA Batteries (4-pack)                 1        2.99
# 149    295800      AAA Batteries (4-pack)                 1        2.99
#
#               Order Date  Month    Sales            City  Hour  \
# ...

# %%
df=df.loc[:,~df.columns.duplicated()]
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date  Month    Sales            City  Hour  \
# ...

# %%
df.nunique()
# Out:
# Order ID            178437
# Product                 19
# Quantity Ordered         9
# Price Each              17
# Order Date          142395
# Month                   12
# Sales                   53
# City                     9
# Hour                    24
# Street               46837
# State Code               8
# ZIP                     10
# dtype: int64

# %%
print(type(df['Order Date']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
# C:\Users\DVM RAJU\AppData\Local\Temp\ipykernel_16044\3347579353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order Date'] = pd.to_datetime(df['Order Date'])
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# ...

# %%
df['Date'] = df['Order Date'].dt.date
df['Time'] = df['Order Date'].dt.time

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                 Order Date  Month    Sales            City  Hour  \
# ...

# %%
df=df.drop(columns='Order Date',axis=1)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  Month  \
# 0         295665      Macbook Pro Laptop                 1     1700.00     12
# 1         295666      LG Washing Machine                 1      600.00     12
# 2         295667    USB-C Charging Cable                 1       11.95     12
# 3         295668        27in FHD Monitor                 1      149.99     12
# 4         295669    USB-C Charging Cable                 1       11.95     12
# ...          ...                     ...               ...         ...    ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99      6
# 185946    222906        27in FHD Monitor                 1      149.99      6
# 185947    222907    USB-C Charging Cable                 1       11.95      6
# 185948    222908    USB-C Charging Cable                 1       11.95      6
# 185949    222909  AAA Batteries (4-pack)                 1        2.99      6
#
# ...

# %%
df=df.rename(columns={'Quantity Ordered':'Qty'})

# %%
df
# Out:
#         Order ID                 Product  Qty  Price Each  Month    Sales  \
# 0         295665      Macbook Pro Laptop    1     1700.00     12  1700.00
# 1         295666      LG Washing Machine    1      600.00     12   600.00
# 2         295667    USB-C Charging Cable    1       11.95     12    11.95
# 3         295668        27in FHD Monitor    1      149.99     12   149.99
# 4         295669    USB-C Charging Cable    1       11.95     12    11.95
# ...          ...                     ...  ...         ...    ...      ...
# 185945    222905  AAA Batteries (4-pack)    1        2.99      6     2.99
# 185946    222906        27in FHD Monitor    1      149.99      6   149.99
# 185947    222907    USB-C Charging Cable    1       11.95      6    11.95
# 185948    222908    USB-C Charging Cable    1       11.95      6    11.95
# 185949    222909  AAA Batteries (4-pack)    1        2.99      6     2.99
#
#                   City  Hour         Street State Code    ZIP        Date  \
# ...

# %%
df.nunique()
# Out:
# Order ID      178437
# Product           19
# Qty                9
# Price Each        17
# Month             12
# Sales             53
# City               9
# Hour              24
# Street         46837
# State Code         8
# ZIP               10
# Date             366
# Time            1440
# dtype: int64

# %%
df['Product'].unique()
# Out:
# array(['Macbook Pro Laptop', 'LG Washing Machine', 'USB-C Charging Cable',
#        '27in FHD Monitor', 'AA Batteries (4-pack)',
#        'Bose SoundSport Headphones', 'AAA Batteries (4-pack)',
#        'ThinkPad Laptop', 'Lightning Charging Cable', 'Google Phone',
#        'Wired Headphones', 'Apple Airpods Headphones', 'Vareebadd Phone',
#        'iPhone', '20in Monitor', '34in Ultrawide Monitor',
#        'Flatscreen TV', '27in 4K Gaming Monitor', 'LG Dryer'],
#       dtype=object)

# %%
df.head()
# Out:
#    Order ID               Product  Qty  Price Each  Month    Sales  \
# 0    295665    Macbook Pro Laptop    1     1700.00     12  1700.00
# 1    295666    LG Washing Machine    1      600.00     12   600.00
# 2    295667  USB-C Charging Cable    1       11.95     12    11.95
# 3    295668      27in FHD Monitor    1      149.99     12   149.99
# 4    295669  USB-C Charging Cable    1       11.95     12    11.95
#
#              City  Hour         Street State Code    ZIP        Date      Time
# 0   New York City     0  136 Church St         NY  10001  2019-12-30  00:01:00
# 1   New York City     7     562 2nd St         NY  10001  2019-12-29  07:03:00
# 2   New York City    18    277 Main St         NY  10001  2019-12-12  18:21:00
# 3   San Francisco    15     410 6th St         CA  94016  2019-12-22  15:13:00
# 4         Atlanta    12     43 Hill St         GA  30301  2019-12-18  12:38:00

# %%
df['City'].unique()
# Out:
# array([' New York City', ' San Francisco', ' Atlanta', ' Portland',
#        ' Dallas', ' Los Angeles', ' Boston', ' Austin', ' Seattle'],
#       dtype=object)

# %%
df['Qty'].unique()
# Out:
# array([1, 2, 4, 3, 7, 5, 6, 8, 9], dtype=int64)

# %%
df['ZIP'].unique()
# Out:
# array(['10001', '94016', '30301', '97035', '75001', '90001', '02215',
#        '73301', '04101', '98101'], dtype=object)

# %%
df['State Code'].unique()
# Out:
# array(['NY', 'CA', 'GA', 'OR', 'TX', 'MA', 'ME', 'WA'], dtype=object)

# %%
df['Street'].unique()
# Out:
# array(['136 Church St', '562 2nd St', '277 Main St', ...,
#        '863 Dogwood St', '735 Highland St', '990 Walnut St'], dtype=object)

# %%
df=df.drop(columns='Street',axis=1)

# %%
df
# Out:
#         Order ID                 Product  Qty  Price Each  Month    Sales  \
# 0         295665      Macbook Pro Laptop    1     1700.00     12  1700.00
# 1         295666      LG Washing Machine    1      600.00     12   600.00
# 2         295667    USB-C Charging Cable    1       11.95     12    11.95
# 3         295668        27in FHD Monitor    1      149.99     12   149.99
# 4         295669    USB-C Charging Cable    1       11.95     12    11.95
# ...          ...                     ...  ...         ...    ...      ...
# 185945    222905  AAA Batteries (4-pack)    1        2.99      6     2.99
# 185946    222906        27in FHD Monitor    1      149.99      6   149.99
# 185947    222907    USB-C Charging Cable    1       11.95      6    11.95
# 185948    222908    USB-C Charging Cable    1       11.95      6    11.95
# 185949    222909  AAA Batteries (4-pack)    1        2.99      6     2.99
#
#                   City  Hour State Code    ZIP        Date      Time
# ...

# %%
numerical=df[['Qty','Price Each','Month','Sales','Hour','Date']]
numerical
# Out:
#         Qty  Price Each  Month    Sales  Hour        Date
# 0         1     1700.00     12  1700.00     0  2019-12-30
# 1         1      600.00     12   600.00     7  2019-12-29
# 2         1       11.95     12    11.95    18  2019-12-12
# 3         1      149.99     12   149.99    15  2019-12-22
# 4         1       11.95     12    11.95    12  2019-12-18
# ...     ...         ...    ...      ...   ...         ...
# 185945    1        2.99      6     2.99    19  2019-06-07
# 185946    1      149.99      6   149.99    19  2019-06-01
# 185947    1       11.95      6    11.95    18  2019-06-22
# 185948    1       11.95      6    11.95    18  2019-06-26
# 185949    1        2.99      6     2.99    14  2019-06-25
#
# [185686 rows x 6 columns]

# %%
plt.figure(figsize=(8,5))
plt.hist(numerical['Qty'])
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(numerical['Price Each'])
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(numerical['Month'])
plt.title('Distribution of Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(numerical['Sales'])
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(numerical['Hour'])
plt.title('Distribution of Hour')
plt.xlabel('Hour')
plt.ylabel('Count')
plt.show()

# %%
product_counts = df['Product'].value_counts()
plt.figure(figsize=(15, 8))
plt.barh(product_counts.index, product_counts.values,height=0.5)  
plt.title('Distribution of Product')
plt.xlabel('Count')
plt.ylabel('Product')           
plt.show()

# %%
city_counts = df['City'].value_counts()
plt.figure(figsize=(15, 8))
plt.barh(city_counts.index, city_counts.values,height=0.7)  
plt.title('Distribution of City')
plt.xlabel('Count')
plt.ylabel('City')           
plt.show()

# %%
df.head()
# Out:
#    Order ID               Product  Qty  Price Each  Month    Sales  \
# 0    295665    Macbook Pro Laptop    1     1700.00     12  1700.00
# 1    295666    LG Washing Machine    1      600.00     12   600.00
# 2    295667  USB-C Charging Cable    1       11.95     12    11.95
# 3    295668      27in FHD Monitor    1      149.99     12   149.99
# 4    295669  USB-C Charging Cable    1       11.95     12    11.95
#
#              City  Hour State Code    ZIP        Date      Time
# 0   New York City     0         NY  10001  2019-12-30  00:01:00
# 1   New York City     7         NY  10001  2019-12-29  07:03:00
# 2   New York City    18         NY  10001  2019-12-12  18:21:00
# 3   San Francisco    15         CA  94016  2019-12-22  15:13:00
# 4         Atlanta    12         GA  30301  2019-12-18  12:38:00

# %%
corr_matrix = df.select_dtypes(include=['number']).corr()
corr_matrix
# Out:
#             Order ID       Qty  Price Each     Month     Sales      Hour
# Order ID    1.000000  0.000739   -0.002854  0.993061 -0.002946  0.001232
# Qty         0.000739  1.000000   -0.148422  0.000831 -0.139564 -0.002211
# Price Each -0.002854 -0.148422    1.000000 -0.003364  0.999202  0.001736
# Month       0.993061  0.000831   -0.003364  1.000000 -0.003454  0.001786
# Sales      -0.002946 -0.139564    0.999202 -0.003454  1.000000  0.001683
# Hour        0.001232 -0.002211    0.001736  0.001786  0.001683  1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm',fmt='0.4f')
plt.title('correlation Matrix')
plt.savefig('Heat Map of')

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(df['Qty'],df['Price Each'])
ax[0, 0].set_title('Quantity vs. Price Each')
ax[0, 0].set_xlabel('Quantity')
ax[0, 0].set_ylabel('Price Each')

ax[0,1].scatter(df['Qty'],df['Month'])
ax[0, 1].set_title('Quantity vs. Month')
ax[0, 1].set_xlabel('Quantity')
ax[0, 1].set_ylabel('Month')

ax[1,0].scatter(df['Qty'],df['Sales'])
ax[1, 0].set_title('Quantity vs. Sales')
ax[1, 0].set_xlabel('Quantity')
ax[1, 0].set_ylabel('Sales')

ax[1,1].scatter(df['Qty'],df['Hour'])
ax[1, 1].set_title('Quantity vs. Hour')
ax[1, 1].set_xlabel('Quantity')
ax[1, 1].set_ylabel('Hour')
plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(df['Price Each'],df['Month'])
ax[0, 0].set_title('Price Each vs. Month')
ax[0, 0].set_xlabel('Price Each')
ax[0, 0].set_ylabel('Month')

ax[0,1].scatter(df['Price Each'],df['Sales'])
ax[0, 1].set_title('Price Each vs. Sales')
ax[0, 1].set_xlabel('Price Each')
ax[0, 1].set_ylabel('Sales')

ax[1,0].scatter(df['Price Each'],df['Hour'])
ax[1, 0].set_title('Price Each vs. Hour')
ax[1, 0].set_xlabel('Price Each')
ax[1, 0].set_ylabel('Hour')

ax[1,1].scatter(df['Price Each'],df['Qty'])
ax[1, 1].set_title('Price Each vs. Quantity')
ax[1, 1].set_xlabel('Price Each')
ax[1, 1].set_ylabel('Quantity')
plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(df['Month'],df['Price Each'])
ax[0, 0].set_title('Month vs. Price')
ax[0, 0].set_xlabel('Month')
ax[0, 0].set_ylabel('Price Each')

ax[0,1].scatter(df['Month'],df['Sales'])
ax[0, 1].set_title('Month vs. Sales')
ax[0, 1].set_xlabel('Month')
ax[0, 1].set_ylabel('Sales')

ax[1,0].scatter(df['Month'],df['Hour'])
ax[1, 0].set_title('Month vs. Hour')
ax[1, 0].set_xlabel('Month')
ax[1, 0].set_ylabel('Hour')

ax[1,1].scatter(df['Month'],df['Qty'])
ax[1, 1].set_title('Month vs. Quantity')
ax[1, 1].set_xlabel('Month')
ax[1, 1].set_ylabel('Quantity')
plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(df['Hour'],df['Price Each'])
ax[0, 0].set_title('Hour vs. Price')
ax[0, 0].set_xlabel('Hour')
ax[0, 0].set_ylabel('Price Each')

ax[0,1].scatter(df['Hour'],df['Sales'])
ax[0, 1].set_title('Hour vs. Sales')
ax[0, 1].set_xlabel('Hour')
ax[0, 1].set_ylabel('Sales')

ax[1,0].scatter(df['Hour'],df['Month'])
ax[1, 0].set_title('Hour vs. Month')
ax[1, 0].set_xlabel('Hour')
ax[1, 0].set_ylabel('Month')

ax[1,1].scatter(df['Hour'],df['Qty'])
ax[1, 1].set_title('Hour vs. Quantity')
ax[1, 1].set_xlabel('Hour')
ax[1, 1].set_ylabel('Quantity')
plt.show()

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(df['Sales'],df['Price Each'])
ax[0, 0].set_title('Sales vs. Price')
ax[0, 0].set_xlabel('Sales')
ax[0, 0].set_ylabel('Price Each')

ax[0,1].scatter(df['Sales'],df['Hour'])
ax[0, 1].set_title('Sales vs. Hour')
ax[0, 1].set_xlabel('Sales')
ax[0, 1].set_ylabel('Hour')

ax[1,0].scatter(df['Sales'],df['Month'])
ax[1, 0].set_title('Sales vs. Month')
ax[1, 0].set_xlabel('Sales')
ax[1, 0].set_ylabel('Month')

ax[1,1].scatter(df['Sales'],df['Qty'])
ax[1, 1].set_title('Sales vs. Quantity')
ax[1, 1].set_xlabel('Sales')
ax[1, 1].set_ylabel('Quantity')
plt.show()

# %%
df.head()
# Out:
#    Order ID               Product  Qty  Price Each  Month    Sales  \
# 0    295665    Macbook Pro Laptop    1     1700.00     12  1700.00
# 1    295666    LG Washing Machine    1      600.00     12   600.00
# 2    295667  USB-C Charging Cable    1       11.95     12    11.95
# 3    295668      27in FHD Monitor    1      149.99     12   149.99
# 4    295669  USB-C Charging Cable    1       11.95     12    11.95
#
#              City  Hour State Code    ZIP        Date      Time
# 0   New York City     0         NY  10001  2019-12-30  00:01:00
# 1   New York City     7         NY  10001  2019-12-29  07:03:00
# 2   New York City    18         NY  10001  2019-12-12  18:21:00
# 3   San Francisco    15         CA  94016  2019-12-22  15:13:00
# 4         Atlanta    12         GA  30301  2019-12-18  12:38:00

# %%
cat_col = ['Product', 'City']
num_col = ['Qty', 'Price Each', 'Month', 'Sales', 'Hour']
plt.figure(figsize=(15,6))  # Create a new figure for each plot
sns.boxplot(x=cat_col[0], y=num_col[0], data=df)
plt.title(f'Box Plot of {num_col[0]} by {cat_col[0]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))  
sns.boxplot(x=cat_col[0], y=num_col[1], data=df)
plt.title(f'Box Plot of {num_col[1]} by {cat_col[0]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))  
sns.boxplot(x=cat_col[0], y=num_col[2], data=df)
plt.title(f'Box Plot of {num_col[2]} by {cat_col[0]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))  
sns.boxplot(x=cat_col[0], y=num_col[3], data=df)
plt.title(f'Box Plot of {num_col[3]} by {cat_col[0]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,6))  
sns.boxplot(x=cat_col[0], y=num_col[4], data=df)
plt.title(f'Box Plot of {num_col[4]} by {cat_col[0]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))  
sns.boxplot(x=cat_col[1], y=num_col[0], data=df)
plt.title(f'Box Plot of {num_col[0]} by {cat_col[1]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))  
sns.boxplot(x=cat_col[1], y=num_col[1], data=df)
plt.title(f'Box Plot of {num_col[1]} by {cat_col[1]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))  
sns.boxplot(x=cat_col[1], y=num_col[2], data=df)
plt.title(f'Box Plot of {num_col[2]} by {cat_col[1]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,4))  
sns.boxplot(x=cat_col[1], y=num_col[3],data=df)
plt.title(f'Box Plot of {num_col[3]} by {cat_col[1]}')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 4))  
sns.boxplot(x=cat_col[1], y=num_col[4],data=df)
plt.title(f'Box Plot of {num_col[4]} by {cat_col[1]}')
plt.xticks(rotation=45)
plt.show()

# %%
pivot_table = df.pivot_table(values= 'Sales', index='Product', columns='City', aggfunc = 'sum')
plt.figure(figsize=(12,8))
sns.heatmap(pivot_table, annot=True, fmt='.0f', cmap='YlGnBu')
plt.title('Heatmap of Sales by Product and City')
plt.show()
